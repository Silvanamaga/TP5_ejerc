# %% [markdown]
# Introducción a las técnicas inteligentes de resolución de problemas de planificación, secuenciación y ejecución

# %% [markdown]
# Ejercicio 1. Escriba un programa en Python que imprima en consola el recorrido de una lista cuyos valores son: mascotas=[“perro”,”gato”, “loro”]

# %%
mascotas = ["perro", "gato", "loro"]
for mascota in mascotas:  # Corregir el nombre de la variable en el bucle
    print("La siguiente mascota es:", mascota)  # Corregir el nombre de la variable en el print y agregar dos puntos al final del bucle
# Out:
# La siguiente mascota es: perro
# La siguiente mascota es: gato
# La siguiente mascota es: loro

# %% [markdown]
# 🌿 En la primera línea lo que hago es crear una lista llamada "mascotas". Es un vector que contiene tres cadenas de texto: "perro", "gato" y "loro".
#
#  👁️ Debo usar comillas simples ¨, no dobles (")
#
# 🌿 En la segunda línea inicié un bucle usando 'for'.
# Por cada elemento en la lista 'mascotas', lo que hago con for es ejecutar el bloque de código. Este bucle for itera sobre cada elemento de la lista "mascotas". En cada iteración, la variable mascota toma el valor del elemento actual en la lista. Va desde el primer al último elemento.
#
#  👁️ En for luego de escribir se colocan dos puntos, es decir se agregan al final de la línea que contiene el bucle for. Estos dos puntos son esenciales en Python para indicar el inicio de un bloque de código.
#
#  👁️El for me permite recorrer una lista. si pongo for mascota recorro mascota, esa variable mascota tiene elementos, el for recorre este vector,sus valores, hasta llegar al final.
# 👁️ Tener en cuenta que:
#      mascotas es el nombre de la lista que contiene todos los elementos, en este
# caso, los diferentes tipos de mascotas.
#      mascota es la variable que utilizamos en el bucle for para iterar sobre
# cada elemento de la lista mascotas.
#
# 👁️ En cada iteración del bucle, mascota toma el valor del elemento actual en la lista. La elección de mascota como nombre de la variable es descriptiva y ayuda a entender que estamos trabajando con elementos individuales de la lista de mascotas. En general conviene usar nombres de variables que sean descriptivos y reflejen el propósito o el contenido de la variable.
#
#  🌿 En la tercera línea uso print así lo veo en pantalla. Dentro del bucle, se imprime un mensaje que indica "La siguiente mascota es:" seguido del valor actual de mascota.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejercicio 2_ Utilice la librería os para listar todos los directorios dentro del directorio “/dev”

# %%
import os

# Para usar la librería os uso el comando "import". 
# obtengo la lista de todos los elementos en el directorio "/dev" para lo que
# uso os.listdir y lo guardo en una variable elementos_dev
elementos_dev = os.listdir("/dev")

# Luego filtro solo los directorios (carpetas) de la lista
directorios_dev = [elemento for elemento in elementos_dev if os.path.isdir(os.path.join("/dev", elemento))]
#El filtro permite obtener solo los directorios del directorio "/dev", excluyendo los archivos
# Imprimo la lista de directorios dentro de "/dev"
print("Directorios dentro de /dev:")
for directorio in directorios_dev:
    print(directorio)
# Out:
# Directorios dentro de /dev:
# dma_heap
# net
# input
# mapper
# bus
# fd
# pts
# char
# disk
# block
# bsg
# shm
# hugepages
# mqueue
# cpu
# vfio
# snd
# dri

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejercicio 3. Hacer un programa en python donde tome dos valores de entrada: sueldo y rango. Con ello, calcule la asignación que percibirá el empleado, considerando la siguiente
# tabla:
# RANGO   FÓRMULA
# 1       sueldo x 0.83
# 2       sueldo x 1.2
# 3       sueldo x 5

# %%
def asignacion_empl(sueldo, rango):
    if rango == 1:
        asignacion = sueldo * 0.83
    elif rango == 2:
        asignacion = sueldo * 1.2
    elif rango == 3:
        asignacion = sueldo * 5
    else:
        asignacion = 0  # Si el rango no es válido, la asignación se establece en 0
        print("Rango no válido. Por favor, seleccione un rango válido.")
    return asignacion

# Función para interactuar con persona usuario, así ingresa datos
def entrada():
    sueldo = float(input("Ingrese el sueldo del empleado: "))
    rango = int(input("Ingrese el rango del empleado (1, 2 o 3): "))
    return sueldo, rango

# Función principal del programa
def main():
    sueldo, rango = entrada()
    asignacion = asignacion_empl(sueldo, rango)
    if asignacion:
        print("La asignación del empleado es:", asignacion)

if __name__ == "__main__":
    main()
# Out:
# La asignación del empleado es: 41.5

# %% [markdown]
#     👁️‍🗨️ elif: Es una abreviatura de "else if". Se utiliza para evaluar otra condición si la condición previa (en el if anterior o en otro elif anterior) no se cumple. En otras palabras, elif se ejecuta solo si las condiciones anteriores no son verdaderas. Puedes tener múltiples bloques elif después de un if.
#
#     👁️‍🗨️ else: Es una cláusula opcional que se utiliza después de todas las cláusulas if y elif en una estructura de control if. Se ejecuta cuando ninguna de las condiciones anteriores es verdadera. Puedes tener solo un bloque else después de todas las cláusulas if y elif.
#
#     La función asignacion_empl() toma el sueldo y el rango como argumentos y devuelve la asignación correspondiente según la tabla.
#     La función entrada() se utiliza para obtener el sueldo y el rango del usuario.
#     La función main() llama a las funciones anteriores, calcula la asignación y la imprime si el rango es válido.
#     Si el rango proporcionado por el usuario no es 1, 2 o 3, el programa imprime un mensaje indicando que el rango no es válido y establecerá la asignación 0.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejercicio 4. Reemplace el ejercicio 3 por una implementación con parámetros pasados por consola usando la librería sys.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys 
print ("El sueldo es:", sys.argv[1])
print ("El rango es: ", sys.argv[2])
#PARA QUE FUNCIONE TENES QUE ESCRIBIR EN LA TERMINAL LO SIGUIENTE: 
#/bin/python3 /home/sil/Documentos/tp5_ej4 1000 1
# los dos últimos valores son los componentes, el primero es sueldo, el segundo el rango. 
# con sys no hago interactivo sino que yo le paso los parámetros juntos. 

def calcular_asignacion(sueldo, rango):
    if rango == 1:
        asignacion = sueldo * 0.83
    elif rango == 2:
        asignacion = sueldo * 1.2
    elif rango == 3:
        asignacion = sueldo * 5
    else:
        asignacion = 0
        print("Rango no válido. Por favor, seleccione un rango válido.")
    return asignacion

def main():
    # Verificar que se proporcionaron dos argumentos (sueldo y rango)
    if len(sys.argv) != 3:
        print("Uso: python programa.py <sueldo> <rango>")
        sys.exit(1)

    # Obtener sueldo y rango de los argumentos
    try:
        sueldo = float(sys.argv[1])
        rango = int(sys.argv[2])
    except ValueError:
        print("Error: Los valores deben ser numéricos.")
        sys.exit(1)

    # Calcular la asignación del empleado
    asignacion = calcular_asignacion(sueldo, rango)
    print("La asignación del empleado es:", asignacion)

if __name__ == "__main__":
    main()

# %% [markdown]
# ![alt text](image.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejercicio 5. Cree un programa en BASH, que invoque a tres programas en python, donde cada
# uno es un contador (con avance cada un segundo) hasta un número que se pase
# por entrada. Cada programa en python debe imprimir el contador
# segundo-a-segundo.
# a. Identifique el PID de cada proceso python
# b. ¿Los procesos de ejecutan de manera secuencial?, ¿Cómo hacer para que
# corran todos a la vez?

# %% [markdown]
# ![alt text](image-1.png)
# ![image.png](attachment:image.png)

# %%
#!/bin/bash
# Ejecutar contador1.py en segundo plano y obtener el PID
python3 cont1 10 & pid1=$!
# Ejecutar contador2.py en segundo plano y obtener el PID
python3 cont2 10 & pid2=$!
# Ejecutar contador3.py en segundo plano y obtener el PID
python3 cont3 10 & pid3=$!
echo "PID del contador 1: $pid1"
echo "PID del contador 2: $pid2"
echo "PID del contador 3: $pid3"

# Esperar a que todos los procesos terminen
wait


#Debes colocar sí o sí en la terminal bash script_bash5
# Out:
#   Cell In[2], line 3
#     python3 cont1 10 & pid1=$!
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# 6. Crea un programa que simule una calculadora simple con funciones para suma,
# resta, multiplicación y división

# %%
def suma(a, b):
    return a + b

def resta(a, b):
    return a - b

def multiplicacion(a, b):
    return a * b

def division(a, b):
    if b != 0:
        return a / b
    else:
        return "Error: División por cero"

def mostrar_menu():
    print("Calculadora Simple")
    print("1. Suma")
    print("2. Resta")
    print("3. Multiplicación")
    print("4. División")
    print("5. Salir")
    return input("Seleccione una opción: ")


while True:
    opcion = mostrar_menu()

    if opcion == '5':
        print("Gracias por usar la calculadora.")
        break

    if opcion not in ['1', '2', '3', '4']:
        print("Opción no válida. Por favor, seleccione una opción válida.")
        continue

    num1 = float(input("Ingrese el primer número: "))
    num2 = float(input("Ingrese el segundo número: "))

    if opcion == '1':
        print("Resultado:", suma(num1, num2))
    elif opcion == '2':
        print("Resultado:", resta(num1, num2))
    elif opcion == '3':
        print("Resultado:", multiplicacion(num1, num2))
    elif opcion == '4':
        print("Resultado:", division(num1, num2))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. Cree un programa en Python que imprima la hora del sistema, estado de memoria
# RAM y almacenamiento disponible en la partición montada en “/”.

# %%
import psutil
from datetime import datetime

def obtener_hora_actual():
    ahora = datetime.now()
    hora_actual = ahora.strftime("%H:%M:%S")
    return hora_actual

def obtener_estado_memoria():
    memoria = psutil.virtual_memory()
    estado = {
        "Total": convertir_bytes(memoria.total),
        "Disponible": convertir_bytes(memoria.available),
        "Usada": convertir_bytes(memoria.used),
        "Porcentaje de uso": f"{memoria.percent}%"
    }
    return estado

def obtener_almacenamiento():
    particion = psutil.disk_usage('/')
    almacenamiento = {
        "Total": convertir_bytes(particion.total),
        "Disponible": convertir_bytes(particion.free),
        "Usado": convertir_bytes(particion.used),
        "Porcentaje de uso": f"{particion.percent}%"
    }
    return almacenamiento

def convertir_bytes(bytes, precision=2):
    kilobytes = bytes / 1024
    megabytes = kilobytes / 1024
    gigabytes = megabytes / 1024
    return round(gigabytes, precision)

def imprimir_info_sistema():
    print("Hora del sistema:", obtener_hora_actual())
    print("Estado de la memoria RAM:")
    memoria = obtener_estado_memoria()
    for key, value in memoria.items():
        print(f"{key}: {value}")
    print("Almacenamiento disponible en la partición /:")
    almacenamiento = obtener_almacenamiento()
    for key, value in almacenamiento.items():
        print(f"{key}: {value}")

imprimir_info_sistema()

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
